# %%
import requests

# %%
a=requests.get("https://firestore.googleapis.com/v1/projects/capestone-945f7/databases/(default)/documents/jobsApplied").json()
a
# Out:
# {'documents': [{'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/9AIXF7u9O3lCiBHx6G6H',
#    'fields': {'loation': {'stringValue': 'Toronto'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20Tatafront-end%20dev%20resume%20sample.pdf?alt=media&token=e5221fdc-4f57-45fc-b0c2-c6efe2b03e69'},
#     'date': {'stringValue': 'Wed Jul 21 2021 22:20:35 GMT-0400 (Eastern Daylight Time)'},
#     'jobDesc': {'stringValue': '<p>The role:</p><p>&nbsp;Reporting to the Manager, Growth Engineering, the Front-End Web Developer will tie their abstract thinking with their technical skills to be a pillar of support within both their team and the Growth department. You\'ll use your skills to build &amp; test on our web properties while collaborating with key stakeholders to understand success on our sites, and use your creativity to balance our analytical mindset.&nbsp;</p><p>The Front-End Web Developer will..&nbsp;</p><p>• Translate design mockups from Figma into responsive HTML and CSS while adhering to best practices for performance, UX, SEO, and accessibility.&nbsp;</p><p>• Update our marketing WordPress sites (getjobber.com and academy.getjobber.com). • Create microsites, web animations and interactive content.&nbsp;</p><p>• Follow brand and design guidelines and bring ideas to collaborative design brainstorms&nbsp;</p><p>• Work with stakeholders on other teams to understand key data metrics. To be successful, you must have:&nbsp;</p><p>• 2-3+ years of experience with semantic HTML, CSS, Javascript, React, PHP in WordPress, and GIT.&nbsp;</p><p>• To collaborate and listen. You\'re supportive and open to opinions outside of your own, have no problem asking others "how can I help?" Or "can I get help?" to clear roadblocks and build relationships, and can take feedback and incorporate it to make your work even better.&nbsp;</p><p>• To be a solid communicator. You\'re adept at working with designers and clients to anticipate challenges, discussing the pros and cons of possible solutions, and deciding on a course of action as a group. • To know how to juggle. We\'re a dynamic start-up, and with that can come change — you need to be comfortable multitasking, prioritizing, and able to estimate/negotiate deadlines.</p><p>&nbsp;• To be ambitious and humble. You don\'t accept the status quo simply because "it\'s what we\'ve always done." You push for better, newer, and more innovative ways to do things — all while staying humble.&nbsp;</p><p>• To be data-focused. It\'s important to understand the impact of your work, you need to learn about our metrics and the impact of increasing or decreasing our conversion rates. That said, we need you to balance this mindset with user research and qualitative feedback. It would be really great (but not a deal-breaker)&nbsp;</p><p>if you had…&nbsp;</p><p>• A post-secondary degree…. • Experience with SCSS, NPM, Node.js or ParcelJS.&nbsp;</p><p>• Experience with SEO. • A/B testing and data science experience.&nbsp;</p><p>• Experience with Modern WordPress and Javascript (gutenberg).</p>'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20Tatafront-end%20dev%20resume%20sample.pdf?alt=media&token=e5221fdc-4f57-45fc-b0c2-c6efe2b03e69'},
#     'id': {'stringValue': 'eyBbM03W6x2ckvJemmjg'},
#     'resumeData': {'mapValue': {'fields': {'total_exp': {'integerValue': '10'},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'themes'},
#           {'stringValue': 'wordpress'},
#           {'stringValue': 'scripting'},
#           {'stringValue': 'multi-platform'},
#           {'stringValue': 'responsiveness'},
#           {'stringValue': 'design'},
#           {'stringValue': 'web api'},
#           {'stringValue': 'graphics'},
#           {'stringValue': 'navigation'},
#           {'stringValue': 'api'},
#           {'stringValue': 'programmers'},
#           {'stringValue': 'languages'},
#           {'stringValue': 'c#'},
#           {'stringValue': 'html5'},
#           {'stringValue': 'fireworks'},
#           {'stringValue': 'mvc'},
#           {'stringValue': 'cms'},
#           {'stringValue': 'creative suite'},
#           {'stringValue': 'functionality'},
#           {'stringValue': 'concrete5'},
#           {'stringValue': 'angular'},
#           {'stringValue': 'testing'},
#           {'stringValue': 'technology'},
#           {'stringValue': 'html'},
#           {'stringValue': 'range'},
#           {'stringValue': 'communications'},
#           {'stringValue': 'jquery'},
#           {'stringValue': 'dp'},
#           {'stringValue': 'c'},
#           {'stringValue': 'typescript'},
#           {'stringValue': 'adobe creative suite'},
#           {'stringValue': 'aweber'},
#           {'stringValue': 'content management'},
#           {'stringValue': 'mailchimp'},
#           {'stringValue': 'photoshop'},
#           {'stringValue': 'asp.net'},
#           {'stringValue': 'asp.net core'},
#           {'stringValue': 'computer science'},
#           {'stringValue': 'optimization'},
#           {'stringValue': 'drupal'},
#           {'stringValue': 'javascript'},
#           {'stringValue': 'json'},
#           {'stringValue': 'adobe'},
#           {'stringValue': 'suite'},
#           {'stringValue': 'excel'},
#           {'stringValue': 'completion'},
#           {'stringValue': 'sql'},
#           {'stringValue': 'web'},
#           {'stringValue': 'training'},
#           {'stringValue': 'user experience'},
#           {'stringValue': 'content management systems'},
#           {'stringValue': 'css'},
#           {'stringValue': 'bootstrap'},
#           {'stringValue': 'web solutions'},
#           {'stringValue': 'scripting languages'},
#           {'stringValue': 'php'},
#           {'stringValue': 'development projects'},
#           {'stringValue': 'fusion'}]}},
#        'email': {'stringValue': 'email@email.com'},
#        'Companies worked at': {'arrayValue': {}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'front end developer'}]}},
#        'degree': {'arrayValue': {}},
#        'name': {'stringValue': 'Viktor Amundsen'},
#        'phone': {'stringValue': '000-000-0000'},
#        'university': {'arrayValue': {}}}}},
#     'jobType': {'stringValue': 'Full-time'},
#     'jobTitle': {'stringValue': 'Front-end WEB Developer'},
#     'userName': {'stringValue': 'Nithin Tata'},
#     'checking': {'stringValue': 'checing'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20Tatafront-end%20dev%20resume%20sample.pdf?alt=media&token=e5221fdc-4f57-45fc-b0c2-c6efe2b03e69'}},
#    'createTime': '2021-07-22T02:20:37.477887Z',
#    'updateTime': '2021-07-22T02:21:20.111526Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/HPX2xiNmRzm8RgJwtijd',
#    'fields': {'checking': {'stringValue': 'checing'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FJaswanth%20TataFinal_CV.pdf?alt=media&token=9b192e75-9c27-4574-bf11-6d7f7ccc743d'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FJaswanth%20TataFinal_CV.pdf?alt=media&token=9b192e75-9c27-4574-bf11-6d7f7ccc743d'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FJaswanth%20TataFinal_CV.pdf?alt=media&token=9b192e75-9c27-4574-bf11-6d7f7ccc743d'},
#     'jobTitle': {'stringValue': 'PLSQL Developer'},
#     'jobDesc': {'stringValue': '<p><strong>The Value You Deliver</strong></p><p>Work with other BI team members to develop Informatica mappings and PL/SQL code to satisfy business requirements</p><p>Analyze data requirements and their impact to the system</p><p>Perform administrative duties for Informatica Power Center application</p><p>Execute unit tests to ensure the accuracy of code changes, and to verify that data integrity and performance requirements are met</p><p>Participate in team’s on-call support schedule, works on incident and enhancement/maintenance tickets assignments and delivers excellent technical support</p><p>Create and maintains technical documents, including data models</p><p>&nbsp;</p><p><strong>What We’re Looking For:</strong></p><p>University Degree, preferably in Computer Science</p><p>2+ years of experience with SQL and PL/SQL development</p><p>1+ years of experience with ETL development, preferably with Informatica Power Center</p><p>1+ years of development experience with Oracle database.</p><p>1+ years of experience with Snowflake data warehouse environment</p><p>&nbsp;</p><p><strong>The Skills You Bring:</strong></p><p>Experience in a Data Warehouse/Business Intelligence environment</p><p>Experience with data modelling tools</p><p>Development experience in Mutual Funds industry is an asset</p><p>Strong technical and data analysis skills</p><p>Excellent problem solving skills</p><p>Customer service oriented</p><p>Good communication skills</p>'},
#     'jobType': {'stringValue': 'Full time'},
#     'loation': {'stringValue': 'Montreal'},
#     'userName': {'stringValue': 'Jaswanth Tata'},
#     'id': {'stringValue': '0q1yyOoSTOQKSJt1yDeh'},
#     'date': {'stringValue': 'Sun Jul 18 2021 20:13:00 GMT+0530 (India Standard Time)'},
#     'resumeData': {'mapValue': {'fields': {'email': {'stringValue': 'prabhleen007kaur@gmail.com(+919711130227)'},
#        'university': {'arrayValue': {}},
#        'Companies worked at': {'arrayValue': {}},
#        'name': {'stringValue': '\u200b Github'},
#        'degree': {'arrayValue': {}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'development intern'}]}},
#        'phone': {'stringValue': '(+919711130227'},
#        'skills': {'arrayValue': {'values': [{'stringValue': '\u200b'},
#           {'stringValue': '● Programming Languages-C/C++'},
#           {'stringValue': 'Java'},
#           {'stringValue': 'Python'},
#           {'stringValue': '● Code Maintainability-Git'},
#           {'stringValue': 'Github'},
#           {'stringValue': ' Firebase'},
#           {'stringValue': '● Android app development-JSON'},
#           {'stringValue': 'XML'},
#           {'stringValue': 'Google Maps etc.'},
#           {'stringValue': '● Miscellaneous- APIs.'},
#           {'stringValue': 'POSITION OF RESPONSIBILITY'},
#           {'stringValue': '● Taarangana - Cultural Fest of IGDTUW (2016-2017):Head Coordinator:Part of the event management team for'},
#           {'stringValue': '\u200b \u200b \u200b'},
#           {'stringValue': 'the college cultural college cultural fest and ensured the smooth functioning of various events during the fest.'},
#           {'stringValue': '● Innerve-Technical Fest of IGDTUW(2016-2017) :Head Coordinator:Organised technical and coding events in'},
#           {'stringValue': 'the fest.'},
#           {'stringValue': '● Rotaract Club of IGDTUW :Member(2016-2017):Social events:Blood Donation Camp'},
#           {'stringValue': 'Campaign for Collection of'},
#           {'stringValue': 'old books and clothes . Leaders for Tomorrow(2015-2016):Volunteered for events like Plantation drive'},
#           {'stringValue': ' Cleanathon'},
#           {'stringValue': '\u200b \u200b'},
#           {'stringValue': 'etc.'}]}},
#        'total_exp': {'integerValue': '2'}}}}},
#    'createTime': '2021-07-18T14:43:01.611695Z',
#    'updateTime': '2021-07-18T14:43:19.717736Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/QmzTLi6GHWrzkLAJdsHW',
#    'fields': {'userName': {'stringValue': 'Nithin Tata'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FNithin%20TataJaswanth.pdf?alt=media&token=dc2803f6-8101-4f4a-8869-fe6604ecf405'},
#     'date': {'stringValue': 'Wed Jul 21 2021 09:16:11 GMT+0530 (India Standard Time)'},
#     'jobType': {'stringValue': 'Full time'},
#     'loation': {'stringValue': 'Montreal'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FNithin%20TataJaswanth.pdf?alt=media&token=dc2803f6-8101-4f4a-8869-fe6604ecf405'},
#     'id': {'stringValue': '0q1yyOoSTOQKSJt1yDeh'},
#     'resumeData': {'mapValue': {'fields': {'university': {'arrayValue': {}},
#        'name': {'stringValue': 'Tata Phone'},
#        'total_exp': {'integerValue': '0'},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'Hindi'},
#           {'stringValue': 'English'},
#           {'stringValue': 'Telugu'}]}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'project engineer'},
#           {'stringValue': 'full stack developer'},
#           {'stringValue': 'backend developer'},
#           {'stringValue': 'fire fighter'}]}},
#        'phone': {'stringValue': '+91 9160024989'},
#        'degree': {'arrayValue': {}},
#        'email': {'stringValue': 'Jaswanthtata@gmail.com'},
#        'Companies worked at': {'arrayValue': {}}}}},
#     'checking': {'stringValue': 'checing'},
#     'jobDesc': {'stringValue': '<p><strong>The Value You Deliver</strong></p><p>Work with other BI team members to develop Informatica mappings and PL/SQL code to satisfy business requirements</p><p>Analyze data requirements and their impact to the system</p><p>Perform administrative duties for Informatica Power Center application</p><p>Execute unit tests to ensure the accuracy of code changes, and to verify that data integrity and performance requirements are met</p><p>Participate in team’s on-call support schedule, works on incident and enhancement/maintenance tickets assignments and delivers excellent technical support</p><p>Create and maintains technical documents, including data models</p><p>&nbsp;</p><p><strong>What We’re Looking For:</strong></p><p>University Degree, preferably in Computer Science</p><p>2+ years of experience with SQL and PL/SQL development</p><p>1+ years of experience with ETL development, preferably with Informatica Power Center</p><p>1+ years of development experience with Oracle database.</p><p>1+ years of experience with Snowflake data warehouse environment</p><p>&nbsp;</p><p><strong>The Skills You Bring:</strong></p><p>Experience in a Data Warehouse/Business Intelligence environment</p><p>Experience with data modelling tools</p><p>Development experience in Mutual Funds industry is an asset</p><p>Strong technical and data analysis skills</p><p>Excellent problem solving skills</p><p>Customer service oriented</p><p>Good communication skills</p>'},
#     'jobTitle': {'stringValue': 'PLSQL Developer'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FNithin%20TataJaswanth.pdf?alt=media&token=dc2803f6-8101-4f4a-8869-fe6604ecf405'}},
#    'createTime': '2021-07-21T03:46:12.583023Z',
#    'updateTime': '2021-07-21T03:46:44.952271Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/XfT38yT7DgGbyarR8FOf',
#    'fields': {'userName': {'stringValue': 'Nithin Tata'},
#     'checking': {'stringValue': 'checing'},
#     'date': {'stringValue': 'Wed Jul 21 2021 11:23:48 GMT-0400 (Eastern Daylight Time)'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20Tatasql%20dev%20resume%20sample.pdf?alt=media&token=4cc6b526-ece7-4981-b700-f4e086486e0b'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20Tatasql%20dev%20resume%20sample.pdf?alt=media&token=4cc6b526-ece7-4981-b700-f4e086486e0b'},
#     'id': {'stringValue': 'z2sLDgTFqKtznZ49aFWM'},
#     'jobTitle': {'stringValue': 'SQL Developer'},
#     'resumeData': {'mapValue': {'fields': {'degree': {'arrayValue': {}},
#        'skills': {'arrayValue': {'values': [{'stringValue': '● -Advanced level proficiency in MSSQL. -Intermediateknowledge of SQL 2014 and SQL 2016.'},
#           {'stringValue': '-Clear communicator in verbal and written English.-Experienced with multiple development'},
#           {'stringValue': 'platforms and software languages. -Strong batch filemanager and application designer. -Dynamic'},
#           {'stringValue': 'presentation and collaboration .'}]}},
#        'name': {'stringValue': 'Viktor Amundsen'},
#        'email': {'stringValue': 'email@email.com'},
#        'phone': {'stringValue': '000-000-0000'},
#        'Companies worked at': {'arrayValue': {}},
#        'university': {'arrayValue': {'values': [{'stringValue': 'university of oregon'}]}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'sql developer'},
#           {'stringValue': 'application designer'},
#           {'stringValue': 'business analyst'},
#           {'stringValue': 'sql report developer'},
#           {'stringValue': 'report developer'},
#           {'stringValue': 'contact person'},
#           {'stringValue': 'business support'}]}},
#        'total_exp': {'integerValue': '10'}}}},
#     'loation': {'stringValue': 'GTA, toronto'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20Tatasql%20dev%20resume%20sample.pdf?alt=media&token=4cc6b526-ece7-4981-b700-f4e086486e0b'},
#     'jobType': {'stringValue': 'Full time'},
#     'jobDesc': {'stringValue': "<p>What You'll Do:</p><ul><li>Analyze metadata requirements to build dashboards and data controls. Implement test automation scripts for those requirements.</li><li>Extract, review and prepare data for analysis &amp; reporting using SQL</li><li>Create and automate test cases using java, python and Selenium Cucumber</li><li>Build &amp; maintain dashboards for monitoring and reporting using BI tools, such as Qlik Sense.</li><li>Facilitate the design discussions to come up with desired technical solution and QA approach.</li><li>Responsible for the conceptualization, design, implementation and testing of metadata capture and data controls; facilitate the data lineage activities and driving anomaly detection initiatives from inception to implementation to test and release.</li></ul><p>Who You’ll Work with:</p><ul><li>Collaborate with Data Governance on metadata and data quality related activities, including integration of our cloud-native data platform with Informatica tools (IDQ, EDC and Axon).</li><li>Work closely with AIML team to identify, create and implement anomaly detection solutions</li><li>Consult with internal and external stakeholders to uphold metadata management best practices</li></ul>"}},
#    'createTime': '2021-07-21T15:23:50.776015Z',
#    'updateTime': '2021-07-21T15:24:29.609982Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/aMWc5Sj1XFVsG4pITXgp',
#    'fields': {'date': {'stringValue': 'Wed Jul 21 2021 09:18:22 GMT+0530 (India Standard Time)'},
#     'id': {'stringValue': 'eyBbM03W6x2ckvJemmjg'},
#     'jobTitle': {'stringValue': 'Front-end WEB Developer'},
#     'resumeData': {'mapValue': {'fields': {'total_exp': {'integerValue': '21'},
#        'phone': {'stringValue': ''},
#        'university': {'arrayValue': {}},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'Machine Learning'},
#           {'stringValue': ' Natural Language Processing'},
#           {'stringValue': ' and Big Data Handling'},
#           {'stringValue': 'Excellent analytical'},
#           {'stringValue': ' problem solving'},
#           {'stringValue': ' communication'},
#           {'stringValue': ' knowledge transfer and interpersonal'},
#           {'stringValue': 'skills with ability to interact with individuals at all the levels'},
#           {'stringValue': 'Quick learner and maintains cordial relationship with project manager and team members and'},
#           {'stringValue': 'good performer both in team and independent job environments'},
#           {'stringValue': 'Positive attitude towards superiors &amp; peers'},
#           {'stringValue': 'Supervised junior developers throughout project lifecycle and provided technical assistance'}]}},
#        'Companies worked at': {'arrayValue': {'values': [{'stringValue': 'Microsoft'}]}},
#        'degree': {'arrayValue': {}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'software engineer'},
#           {'stringValue': 'pick up'},
#           {'stringValue': 'project manager'}]}},
#        'email': {'nullValue': None},
#        'name': {'stringValue': 'Alice Clark'}}}},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=e7cf03b9-d784-4e4c-8496-925dd5953bf9'},
#     'loation': {'stringValue': 'Toronto'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=e7cf03b9-d784-4e4c-8496-925dd5953bf9'},
#     'checking': {'stringValue': 'checing'},
#     'jobDesc': {'stringValue': '<p>The role:</p><p>&nbsp;Reporting to the Manager, Growth Engineering, the Front-End Web Developer will tie their abstract thinking with their technical skills to be a pillar of support within both their team and the Growth department. You\'ll use your skills to build &amp; test on our web properties while collaborating with key stakeholders to understand success on our sites, and use your creativity to balance our analytical mindset.&nbsp;</p><p>The Front-End Web Developer will..&nbsp;</p><p>• Translate design mockups from Figma into responsive HTML and CSS while adhering to best practices for performance, UX, SEO, and accessibility.&nbsp;</p><p>• Update our marketing WordPress sites (getjobber.com and academy.getjobber.com). • Create microsites, web animations and interactive content.&nbsp;</p><p>• Follow brand and design guidelines and bring ideas to collaborative design brainstorms&nbsp;</p><p>• Work with stakeholders on other teams to understand key data metrics. To be successful, you must have:&nbsp;</p><p>• 2-3+ years of experience with semantic HTML, CSS, Javascript, React, PHP in WordPress, and GIT.&nbsp;</p><p>• To collaborate and listen. You\'re supportive and open to opinions outside of your own, have no problem asking others "how can I help?" Or "can I get help?" to clear roadblocks and build relationships, and can take feedback and incorporate it to make your work even better.&nbsp;</p><p>• To be a solid communicator. You\'re adept at working with designers and clients to anticipate challenges, discussing the pros and cons of possible solutions, and deciding on a course of action as a group. • To know how to juggle. We\'re a dynamic start-up, and with that can come change — you need to be comfortable multitasking, prioritizing, and able to estimate/negotiate deadlines.</p><p>&nbsp;• To be ambitious and humble. You don\'t accept the status quo simply because "it\'s what we\'ve always done." You push for better, newer, and more innovative ways to do things — all while staying humble.&nbsp;</p><p>• To be data-focused. It\'s important to understand the impact of your work, you need to learn about our metrics and the impact of increasing or decreasing our conversion rates. That said, we need you to balance this mindset with user research and qualitative feedback. It would be really great (but not a deal-breaker)&nbsp;</p><p>if you had…&nbsp;</p><p>• A post-secondary degree…. • Experience with SCSS, NPM, Node.js or ParcelJS.&nbsp;</p><p>• Experience with SEO. • A/B testing and data science experience.&nbsp;</p><p>• Experience with Modern WordPress and Javascript (gutenberg).</p>'},
#     'jobType': {'stringValue': 'Full-time'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=e7cf03b9-d784-4e4c-8496-925dd5953bf9'},
#     'userName': {'stringValue': 'Nithin Tata'}},
#    'createTime': '2021-07-21T03:48:24.145199Z',
#    'updateTime': '2021-07-21T03:48:35.797811Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/bEgvp4QLsCK4KMnezcqy',
#    'fields': {'checking': {'stringValue': 'checing'},
#     'jobDesc': {'stringValue': "<p>What You'll Do:</p><ul><li>Analyze metadata requirements to build dashboards and data controls. Implement test automation scripts for those requirements.</li><li>Extract, review and prepare data for analysis &amp; reporting using SQL</li><li>Create and automate test cases using java, python and Selenium Cucumber</li><li>Build &amp; maintain dashboards for monitoring and reporting using BI tools, such as Qlik Sense.</li><li>Facilitate the design discussions to come up with desired technical solution and QA approach.</li><li>Responsible for the conceptualization, design, implementation and testing of metadata capture and data controls; facilitate the data lineage activities and driving anomaly detection initiatives from inception to implementation to test and release.</li></ul><p>Who You’ll Work with:</p><ul><li>Collaborate with Data Governance on metadata and data quality related activities, including integration of our cloud-native data platform with Informatica tools (IDQ, EDC and Axon).</li><li>Work closely with AIML team to identify, create and implement anomaly detection solutions</li><li>Consult with internal and external stakeholders to uphold metadata management best practices</li></ul>"},
#     'userName': {'stringValue': 'Nithin Tata'},
#     'id': {'stringValue': 'z2sLDgTFqKtznZ49aFWM'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=7001f21c-ee70-40f4-8843-95fa018ea2fe'},
#     'jobTitle': {'stringValue': 'SQL Developer'},
#     'resumeData': {'mapValue': {'fields': {'total_exp': {'integerValue': '21'},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'software engineer'},
#           {'stringValue': 'pick up'},
#           {'stringValue': 'project manager'}]}},
#        'email': {'nullValue': None},
#        'university': {'arrayValue': {}},
#        'Companies worked at': {'arrayValue': {'values': [{'stringValue': 'Microsoft'}]}},
#        'degree': {'arrayValue': {}},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'Machine Learning'},
#           {'stringValue': ' Natural Language Processing'},
#           {'stringValue': ' and Big Data Handling'},
#           {'stringValue': 'Excellent analytical'},
#           {'stringValue': ' problem solving'},
#           {'stringValue': ' communication'},
#           {'stringValue': ' knowledge transfer and interpersonal'},
#           {'stringValue': 'skills with ability to interact with individuals at all the levels'},
#           {'stringValue': 'Quick learner and maintains cordial relationship with project manager and team members and'},
#           {'stringValue': 'good performer both in team and independent job environments'},
#           {'stringValue': 'Positive attitude towards superiors &amp; peers'},
#           {'stringValue': 'Supervised junior developers throughout project lifecycle and provided technical assistance'}]}},
#        'name': {'stringValue': 'Alice Clark'},
#        'phone': {'stringValue': ''}}}},
#     'jobType': {'stringValue': 'Full time'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=7001f21c-ee70-40f4-8843-95fa018ea2fe'},
#     'date': {'stringValue': 'Wed Jul 21 2021 09:22:00 GMT+0530 (India Standard Time)'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=7001f21c-ee70-40f4-8843-95fa018ea2fe'},
#     'loation': {'stringValue': 'GTA, toronto'}},
#    'createTime': '2021-07-21T03:52:01.519263Z',
#    'updateTime': '2021-07-21T03:52:33.253630Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/eJtlFxByJA31YDTxh6rk',
#    'fields': {'jobTitle': {'stringValue': 'PLSQL Developer'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2Fjaswanth%20tataResume%20(6).pdf?alt=media&token=5eafe03f-7dfc-455e-b631-d0aa7ca92478'},
#     'checking': {'stringValue': 'checing'},
#     'loation': {'stringValue': 'Montreal'},
#     'jobDesc': {'stringValue': '<p><strong>The Value You Deliver</strong></p><p>Work with other BI team members to develop Informatica mappings and PL/SQL code to satisfy business requirements</p><p>Analyze data requirements and their impact to the system</p><p>Perform administrative duties for Informatica Power Center application</p><p>Execute unit tests to ensure the accuracy of code changes, and to verify that data integrity and performance requirements are met</p><p>Participate in team’s on-call support schedule, works on incident and enhancement/maintenance tickets assignments and delivers excellent technical support</p><p>Create and maintains technical documents, including data models</p><p>&nbsp;</p><p><strong>What We’re Looking For:</strong></p><p>University Degree, preferably in Computer Science</p><p>2+ years of experience with SQL and PL/SQL development</p><p>1+ years of experience with ETL development, preferably with Informatica Power Center</p><p>1+ years of development experience with Oracle database.</p><p>1+ years of experience with Snowflake data warehouse environment</p><p>&nbsp;</p><p><strong>The Skills You Bring:</strong></p><p>Experience in a Data Warehouse/Business Intelligence environment</p><p>Experience with data modelling tools</p><p>Development experience in Mutual Funds industry is an asset</p><p>Strong technical and data analysis skills</p><p>Excellent problem solving skills</p><p>Customer service oriented</p><p>Good communication skills</p>'},
#     'date': {'stringValue': 'Wed Jul 21 2021 20:51:02 GMT+0530 (India Standard Time)'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2Fjaswanth%20tataResume%20(6).pdf?alt=media&token=5eafe03f-7dfc-455e-b631-d0aa7ca92478'},
#     'resumeData': {'mapValue': {'fields': {'phone': {'stringValue': '+91 9160024989'},
#        'university': {'arrayValue': {}},
#        'Companies worked at': {'arrayValue': {}},
#        'total_exp': {'integerValue': '0'},
#        'name': {'stringValue': 'Tata Phone'},
#        'email': {'stringValue': 'Jaswanthtata@gmail.com'},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'Hindi'},
#           {'stringValue': 'English'},
#           {'stringValue': 'Telugu'}]}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'project engineer'},
#           {'stringValue': 'full stack developer'},
#           {'stringValue': 'backend developer'},
#           {'stringValue': 'fire fighter'}]}},
#        'degree': {'arrayValue': {}}}}},
#     'jobType': {'stringValue': 'Full time'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2Fjaswanth%20tataResume%20(6).pdf?alt=media&token=5eafe03f-7dfc-455e-b631-d0aa7ca92478'},
#     'userName': {'stringValue': 'jaswanth tata'},
#     'id': {'stringValue': '0q1yyOoSTOQKSJt1yDeh'}},
#    'createTime': '2021-07-21T15:21:03.320959Z',
#    'updateTime': '2021-07-21T15:21:37.727536Z'},
#   {'name': 'projects/capestone-945f7/databases/(default)/documents/jobsApplied/rbDUNkCaJgR2uYqdsJVR',
#    'fields': {'jobTitle': {'stringValue': 'Front-end WEB Developer'},
#     'userName': {'stringValue': 'Jaswanth Tata'},
#     'id': {'stringValue': 'eyBbM03W6x2ckvJemmjg'},
#     'url': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FJaswanth%20TataJalpaDave_CV.pdf?alt=media&token=268d550f-6e69-4c05-9bc3-fc1558eb6c13'},
#     'loation': {'stringValue': 'Toronto'},
#     'jobDesc': {'stringValue': '<p>The role:</p><p>&nbsp;Reporting to the Manager, Growth Engineering, the Front-End Web Developer will tie their abstract thinking with their technical skills to be a pillar of support within both their team and the Growth department. You\'ll use your skills to build &amp; test on our web properties while collaborating with key stakeholders to understand success on our sites, and use your creativity to balance our analytical mindset.&nbsp;</p><p>The Front-End Web Developer will..&nbsp;</p><p>• Translate design mockups from Figma into responsive HTML and CSS while adhering to best practices for performance, UX, SEO, and accessibility.&nbsp;</p><p>• Update our marketing WordPress sites (getjobber.com and academy.getjobber.com). • Create microsites, web animations and interactive content.&nbsp;</p><p>• Follow brand and design guidelines and bring ideas to collaborative design brainstorms&nbsp;</p><p>• Work with stakeholders on other teams to understand key data metrics. To be successful, you must have:&nbsp;</p><p>• 2-3+ years of experience with semantic HTML, CSS, Javascript, React, PHP in WordPress, and GIT.&nbsp;</p><p>• To collaborate and listen. You\'re supportive and open to opinions outside of your own, have no problem asking others "how can I help?" Or "can I get help?" to clear roadblocks and build relationships, and can take feedback and incorporate it to make your work even better.&nbsp;</p><p>• To be a solid communicator. You\'re adept at working with designers and clients to anticipate challenges, discussing the pros and cons of possible solutions, and deciding on a course of action as a group. • To know how to juggle. We\'re a dynamic start-up, and with that can come change — you need to be comfortable multitasking, prioritizing, and able to estimate/negotiate deadlines.</p><p>&nbsp;• To be ambitious and humble. You don\'t accept the status quo simply because "it\'s what we\'ve always done." You push for better, newer, and more innovative ways to do things — all while staying humble.&nbsp;</p><p>• To be data-focused. It\'s important to understand the impact of your work, you need to learn about our metrics and the impact of increasing or decreasing our conversion rates. That said, we need you to balance this mindset with user research and qualitative feedback. It would be really great (but not a deal-breaker)&nbsp;</p><p>if you had…&nbsp;</p><p>• A post-secondary degree…. • Experience with SCSS, NPM, Node.js or ParcelJS.&nbsp;</p><p>• Experience with SEO. • A/B testing and data science experience.&nbsp;</p><p>• Experience with Modern WordPress and Javascript (gutenberg).</p>'},
#     'jobType': {'stringValue': 'Full-time'},
#     'checking': {'stringValue': 'checing'},
#     'resumeData': {'mapValue': {'fields': {'email': {'nullValue': None},
#        'phone': {'stringValue': ''},
#        'total_exp': {'integerValue': '5'},
#        'degree': {'arrayValue': {}},
#        'designition': {'arrayValue': {'values': [{'stringValue': 'data scientist'},
#           {'stringValue': 'scientist'},
#           {'stringValue': 'web analyst'}]}},
#        'name': {'stringValue': 'Jalpa Dave'},
#        'skills': {'arrayValue': {'values': [{'stringValue': 'ALGORITHMS (1 year)'},
#           {'stringValue': ' APACHE (1 year)'},
#           {'stringValue': ' JAVA (1 year)'},
#           {'stringValue': ' SCRIPTING (1 year)'},
#           {'stringValue': ' API (Less than 1'},
#           {'stringValue': 'year)'},
#           {'stringValue': 'Operating System Windows'},
#           {'stringValue': ' Unix'},
#           {'stringValue': ' Linux.'},
#           {'stringValue': 'Programming Language R'},
#           {'stringValue': ' Python'},
#           {'stringValue': ' SQL'},
#           {'stringValue': ' C#.NET'},
#           {'stringValue': ' Visual Basic.NET'},
#           {'stringValue': ' Java.'},
#           {'stringValue': 'Database MS Excel'},
#           {'stringValue': ' MS Access'},
#           {'stringValue': ' Oracle'},
#           {'stringValue': ' SQL Server 2000.'},
#           {'stringValue': 'Mark Up / Scripting'},
#           {'stringValue': 'HTML'},
#           {'stringValue': ' ASP'},
#           {'stringValue': ' ASP.NET'},
#           {'stringValue': ' Core Java &amp; Advanced Java'},
#           {'stringValue': 'Language/Web'},
#           {'stringValue': 'Programming.'},
#           {'stringValue': 'Packages/Tools Apache Spark'},
#           {'stringValue': ' Google Analytics'},
#           {'stringValue': ' Google BigQuery'},
#           {'stringValue': ' Google'},
#           {'stringValue': 'Prediction API'},
#           {'stringValue': ' R Studio'},
#           {'stringValue': ' Rattle'},
#           {'stringValue': ' Shiny'},
#           {'stringValue': ' XLMiner'},
#           {'stringValue': ' Weka'},
#           {'stringValue': ' Rapid'},
#           {'stringValue': 'Miner'},
#           {'stringValue': ' Tanagra.'},
#           {'stringValue': 'Theories Data Mining'},
#           {'stringValue': ' Object Oriented Analysis &amp; Design'},
#           {'stringValue': ' Management'},
#           {'stringValue': 'Information system'},
#           {'stringValue': ' Data Structure &amp; Algorithms'},
#           {'stringValue': ' Advanced'},
#           {'stringValue': 'Database Management System'},
#           {'stringValue': ' Operating Systems'},
#           {'stringValue': ' System'},
#           {'stringValue': 'Analysis and Design &amp; Unified Modelling Language'},
#           {'stringValue': ' Software'},
#           {'stringValue': 'Engineering'},
#           {'stringValue': ' .NET Platform'},
#           {'stringValue': ' Technical writing.'}]}},
#        'university': {'arrayValue': {'values': [{'stringValue': 'saurashtra university'}]}},
#        'Companies worked at': {'arrayValue': {'values': [{'stringValue': 'Elegant Microweb Technologies Private Limited'}]}}}}},
#     'date': {'stringValue': 'Sun Jul 18 2021 20:13:37 GMT+0530 (India Standard Time)'},
#     'original': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FJaswanth%20TataJalpaDave_CV.pdf?alt=media&token=268d550f-6e69-4c05-9bc3-fc1558eb6c13'},
#     'gotUrl': {'stringValue': 'https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FJaswanth%20TataJalpaDave_CV.pdf?alt=media&token=268d550f-6e69-4c05-9bc3-fc1558eb6c13'}},
#    'createTime': '2021-07-18T14:43:37.246591Z',
#    'updateTime': '2021-07-18T14:44:10.571876Z'}]}

# %%
for aa in a["documents"]:
    print(aa["fields"]["url"]["stringValue"])
# Out:
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20Tatafront-end%20dev%20resume%20sample.pdf?alt=media&token=e5221fdc-4f57-45fc-b0c2-c6efe2b03e69
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FJaswanth%20TataFinal_CV.pdf?alt=media&token=9b192e75-9c27-4574-bf11-6d7f7ccc743d
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2FNithin%20TataJaswanth.pdf?alt=media&token=dc2803f6-8101-4f4a-8869-fe6604ecf405
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20Tatasql%20dev%20resume%20sample.pdf?alt=media&token=4cc6b526-ece7-4981-b700-f4e086486e0b
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=e7cf03b9-d784-4e4c-8496-925dd5953bf9
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/z2sLDgTFqKtznZ49aFWM%2FNithin%20TataAlice%20Clark%20CV.pdf?alt=media&token=7001f21c-ee70-40f4-8843-95fa018ea2fe
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/0q1yyOoSTOQKSJt1yDeh%2Fjaswanth%20tataResume%20(6).pdf?alt=media&token=5eafe03f-7dfc-455e-b631-d0aa7ca92478
# https://firebasestorage.googleapis.com/v0/b/capestone-945f7.appspot.com/o/eyBbM03W6x2ckvJemmjg%2FJaswanth%20TataJalpaDave_CV.pdf?alt=media&token=268d550f-6e69-4c05-9bc3-fc1558eb6c13
